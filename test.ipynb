# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from MarketAnalysis import analyser

# %%
c = analyser.StockAnalyser()

# %%
# c.__df

# %%
c.grab_data_from_yahoo('bili')

# %%
c.plot(c.get_volume())

# %%
c.save_to_csv('output/bili.csv')

# %%
c.load_csv('input/bili.csv')

# %%
#======================================

# %%
from MarketAnalysis.analyser import StockAnalyser
from MarketAnalysis.plot import plot, fancy_plot, plot_histogram

# %%
AAPL = StockAnalyser('AAPL')
AAPL.load_data_from_yahoo()
# Out:
# Data grabbed successfully from Yahoo! Finance. Here's a peek
#                   High         Low        Open       Close      Volume  \
# Date
# 2018-07-23  191.960007  189.559998  190.679993  191.610001  15989400.0
# 2018-07-24  193.660004  192.050003  192.449997  193.000000  18697900.0
# 2018-07-25  194.850006  192.429993  193.059998  194.820007  16709900.0
# 2018-07-26  195.960007  193.610001  194.610001  194.210007  19076000.0
# 2018-07-27  195.190002  190.100006  194.990005  190.979996  24024000.0
#
#              Adj Close
# Date
# 2018-07-23  188.737030
# 2018-07-24  190.106216
# 2018-07-25  191.898926
# 2018-07-26  191.298080
# 2018-07-27  188.116501

# %%
AAPL.full_df().reset_index()
# Out:
#           Date        High         Low        Open       Close      Volume  \
# 0   2018-07-23  191.960007  189.559998  190.679993  191.610001  15989400.0
# 1   2018-07-24  193.660004  192.050003  192.449997  193.000000  18697900.0
# 2   2018-07-25  194.850006  192.429993  193.059998  194.820007  16709900.0
# 3   2018-07-26  195.960007  193.610001  194.610001  194.210007  19076000.0
# 4   2018-07-27  195.190002  190.100006  194.990005  190.979996  24024000.0
# 5   2018-07-30  192.199997  189.070007  191.899994  189.910004  21029500.0
# 6   2018-07-31  192.139999  189.339996  190.300003  190.289993  39373000.0
# 7   2018-08-01  201.759995  197.309998  199.130005  201.500000  67935700.0
# 8   2018-08-02  208.380005  200.350006  200.580002  207.389999  62404000.0
# 9   2018-08-03  208.740005  205.479996  207.029999  207.990005  33447400.0
# 10  2018-08-06  209.250000  207.070007  208.000000  209.070007  25425400.0
# ...
